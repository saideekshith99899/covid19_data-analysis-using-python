# %%
import pandas as pd

# %%
covid = pd.read_csv(r"C:\Users\Sai Deekshith\Downloads\covid.csv");

# %%
covid
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
covid.shape
# Out:
# (321, 6)

# %%
covid.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
covid.index
# Out:
# RangeIndex(start=0, stop=321, step=1)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
covid.describe()
# Out:
#            Confirmed        Deaths      Recovered
# count     321.000000    321.000000     321.000000
# mean     9949.800623    709.152648    3030.277259
# std     31923.853086   3236.162817   14364.870365
# min         0.000000      0.000000       0.000000
# 25%       104.000000      2.000000       2.000000
# 50%       653.000000     12.000000      73.000000
# 75%      4655.000000    144.000000     587.000000
# max    299691.000000  27682.000000  132929.000000

# %%
covid.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %%
covid.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# %%
sns.heatmap(covid.isnull()) 
plt.show()

# %%
covid.head(10)
# Out:
#         Date State               Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN          Afghanistan       1939      60        252
# 1  4/29/2020   NaN              Albania        766      30        455
# 2  4/29/2020   NaN              Algeria       3848     444       1702
# 3  4/29/2020   NaN              Andorra        743      42        423
# 4  4/29/2020   NaN               Angola         27       2          7
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11
# 6  4/29/2020   NaN            Argentina       4285     214       1192
# 7  4/29/2020   NaN              Armenia       1932      30        900
# 8  4/29/2020   NaN              Austria      15402     580      12779
# 9  4/29/2020   NaN           Azerbaijan       1766      23       1267

# %%
covid.groupby('Region').sum().head(50)
# Out:
#                           Confirmed  Deaths  Recovered
# Region
# Afghanistan                    1939      60        252
# Albania                         766      30        455
# Algeria                        3848     444       1702
# Andorra                         743      42        423
# Angola                           27       2          7
# Antigua and Barbuda              24       3         11
# Argentina                      4285     214       1192
# Armenia                        1932      30        900
# Australia                      6752      91       5715
# Austria                       15402     580      12779
# Azerbaijan                     1766      23       1267
# Bahamas                          80      11         23
# Bahrain                        2921       8       1455
# Bangladesh                     7103     163        150
# Barbados                         80       7         39
# Belarus                       13181      84       2072
# ...

# %%
covid.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(50)
# Out:
# Region
# US                      1039909
# Spain                    236899
# Italy                    203591
# France                   166543
# UK                       166441
# Germany                  161539
# Turkey                   117589
# Russia                    99399
# Iran                      93657
# Mainland China            82862
# Brazil                    79685
# Canada                    52865
# Belgium                   47859
# Netherlands               38998
# Peru                      33931
# India                     33062
# Switzerland               29407
# Ecuador                   24675
# Portugal                  24505
# Saudi Arabia              21402
# Sweden                    20302
# Ireland                   20253
# Mexico                    17799
# Israel                    15834
# Singapore                 15641
# Pakistan                  15525
# Austria                   15402
# Chile                     14885
# Japan                     13895
# ...

# %%
covid.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
covid.groupby('Date').sum().head(50)
# Out:
#            Confirmed  Deaths  Recovered
# Date
# 4/29/2020    3193886  227638     972719

# %%
covid.head(4)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423

# %%
covid.Confirmed.sum()
# Out:
# 3193886

# %%
covid.Deaths.sum()
# Out:
# 227638

# %%
covid.Recovered.sum()
# Out:
# 972719

# %%
covid.shape
# Out:
# (321, 6)

# %%
covid.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
covid.index
# Out:
# RangeIndex(start=0, stop=321, step=1)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
covid.groupby('Confirmed').sum().head(10)
# Out:
#            Deaths  Recovered
# Confirmed
# 0               1     141047
# 1               0          1
# 3               0          3
# 5               0          0
# 6               1         15
# 7               0          5
# 8               1         10
# 9               2          0
# 10              2         18
# 11              2         23

# %%
covid.groupby('Deaths').sum()
# Out:
#         Confirmed  Recovered
# Deaths
# 0            3440     143479
# 1            4463       3227
# 2            2573       1654
# 3            2257       1417
# 4            3705       2914
# ...           ...        ...
# 23477      299691          0
# 24087      165093      48228
# 24275      236899     132929
# 26097      165221          0
# 27682      203591      71252
#
# [142 rows x 2 columns]

# %%
covid.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
covid.groupby('Region').sum().head(10)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779

# %%
covid.groupby('Region').sum().tail(10)
# Out:
#                       Confirmed  Deaths  Recovered
# Region
# United Arab Emirates      11929      98       2329
# Uruguay                     630      15        412
# Uzbekistan                 2002       9       1096
# Venezuela                   331      10        142
# Vietnam                     270       0        222
# West Bank and Gaza          344       2         71
# Western Sahara                6       0          5
# Yemen                         6       0          1
# Zambia                       97       3         54
# Zimbabwe                     32       4          5

# %%
covid.groupby('Region')['Confirmed'].sum().sort_values(ascending = False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %%
covid.groupby("Region")['Confirmed'].sum().sort_values(ascending = True)
# Out:
# Region
# Yemen                          6
# Western Sahara                 6
# Bhutan                         7
# Papua New Guinea               8
# Sao Tome and Principe          8
#                           ...
# UK                        166441
# France                    166543
# Italy                     203591
# Spain                     236899
# US                       1039909
# Name: Confirmed, Length: 187, dtype: int64

# %%
covid.groupby("Region")["Deaths"].sum().sort_values(ascending = False)
# Out:
# Region
# US             60967
# Italy          27682
# UK             26166
# Spain          24275
# France         24121
#                ...
# Holy See           0
# Grenada            0
# South Sudan        0
# Nepal              0
# Laos               0
# Name: Deaths, Length: 187, dtype: int64

# %%
covid.groupby("Region")["Recovered"].sum().sort_values(ascending = True)
# Out:
# Region
# Papua New Guinea         0
# South Sudan              0
# MS Zaandam               0
# Yemen                    1
# Cabo Verde               2
#                      ...
# Iran                 73791
# Mainland China       77610
# Germany             120400
# US                  120720
# Spain               132929
# Name: Recovered, Length: 187, dtype: int64

# %%
covid.groupby('Confirmed')['Deaths'].sum().sort_values(ascending = False)
# Out:
# Confirmed
# 203591    27682
# 165221    26097
# 236899    24275
# 165093    24087
# 299691    23477
#           ...
# 45            0
# 49            0
# 50            0
# 58            0
# 20            0
# Name: Deaths, Length: 282, dtype: int64

# %%
covid.groupby('Region')['Confirmed','Deaths'].sum()
# Out:
# C:\Users\Sai Deekshith\AppData\Local\Temp\ipykernel_31564\3655135836.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   covid.groupby('Region')['Confirmed','Deaths'].sum()
#                     Confirmed  Deaths
# Region
# Afghanistan              1939      60
# Albania                   766      30
# Algeria                  3848     444
# Andorra                   743      42
# Angola                     27       2
# ...                       ...     ...
# West Bank and Gaza        344       2
# Western Sahara              6       0
# Yemen                       6       0
# Zambia                     97       3
# Zimbabwe                   32       4
#
# [187 rows x 2 columns]

# %%
covid
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
covidx = pd.read_csv(r"C:\Users\Sai Deekshith\Downloads\covid.csv");

# %%
covidx
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
covidx = covidx[~(covidx.Confirmed < 10)]

# %%
covidx
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
covidxx = covidx.Confirmed.max()
covidxx
# Out:
# 299691

# %%
covidx.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Name: Confirmed, dtype: int64

# %%
covidx.groupby('Region')["Deaths"].sum().sort_values(ascending = True).max()
# Out:
# 60967

# %%
covid
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
covid.State
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 316     Wyoming
# 317    Xinjiang
# 318       Yukon
# 319      Yunnan
# 320    Zhejiang
# Name: State, Length: 321, dtype: object

# %%
covid.State.value_counts()
# Out:
# Grand Princess                  2
# Recovered                       2
# Diamond Princess cruise ship    2
# Alabama                         1
# Oregon                          1
#                                ..
# Hawaii                          1
# Hainan                          1
# Guizhou                         1
# Guangxi                         1
# Zhejiang                        1
# Name: State, Length: 137, dtype: int64

# %%
covid.State.nunique()
# Out:
# 137

# %%
covid[covid.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
covid_df = covid.head(10)

# %%
covid_df
# Out:
#         Date State               Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN          Afghanistan       1939      60        252
# 1  4/29/2020   NaN              Albania        766      30        455
# 2  4/29/2020   NaN              Algeria       3848     444       1702
# 3  4/29/2020   NaN              Andorra        743      42        423
# 4  4/29/2020   NaN               Angola         27       2          7
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11
# 6  4/29/2020   NaN            Argentina       4285     214       1192
# 7  4/29/2020   NaN              Armenia       1932      30        900
# 8  4/29/2020   NaN              Austria      15402     580      12779
# 9  4/29/2020   NaN           Azerbaijan       1766      23       1267

# %%
covid_df.shape
# Out:
# (10, 6)

# %%
import numpy as np
import matplotlib as plt

# %%
import matplotlib.pyplot as plt
plt.plot(covid_df.Confirmed)
plt.show()

# %%
covid
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
covid.sort_values(by = ['Confirmed'], ascending = False)
# Out:
#           Date                         State          Region  Confirmed  \
# 265  4/29/2020                      New York              US     299691
# 153  4/29/2020                           NaN           Spain     236899
# 80   4/29/2020                           NaN           Italy     203591
# 168  4/29/2020                           NaN              UK     165221
# 57   4/29/2020                           NaN          France     165093
# ..         ...                           ...             ...        ...
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
#
#      Deaths  Recovered
# 265   23477          0
# 153   24275     132929
# 80    27682      71252
# ...

# %%
covid.sort_values(by = ["Deaths"],ascending = False)
# Out:
#           Date          State  Region  Confirmed  Deaths  Recovered
# 80   4/29/2020            NaN   Italy     203591   27682      71252
# 168  4/29/2020            NaN      UK     165221   26097          0
# 153  4/29/2020            NaN   Spain     236899   24275     132929
# 57   4/29/2020            NaN  France     165093   24087      48228
# 265  4/29/2020       New York      US     299691   23477          0
# ..         ...            ...     ...        ...     ...        ...
# 55   4/29/2020            NaN    Fiji         18       0         12
# 284  4/29/2020      Recovered  Canada          0       0      20327
# 285  4/29/2020      Recovered      US          0       0     120720
# 286  4/29/2020        Reunion  France        420       0        300
# 259  4/29/2020  New Brunswick  Canada        118       0          0
#
# [321 rows x 6 columns]
